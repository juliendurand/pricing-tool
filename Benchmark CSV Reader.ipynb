# %%
# %%time

from time import perf_counter 

import numpy as np
import pandas as pd
import dask
import dask.dataframe as dd
import dask.bag as bag

import dask.multiprocessing

#from dask.distributed import Client
#client = Client()
# Out:
# CPU times: user 18 µs, sys: 1e+03 ns, total: 19 µs
# Wall time: 22.9 µs

# %%
start_counter = perf_counter()
reader = pd.read_csv('./data/axaf_mrh_ddea_freq_tot.csv', chunksize=100000, iterator=True, dtype=mrh_dtypes)
for chunk in reader:
    print("a")
#df = df.astype('category')
stop_counter = perf_counter()
duration = stop_counter - start_counter
print('Duration: ', duration, ', Speed : ', 2920 / duration, ' MB/s')
# Out:
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# Duration:  210.98390259699954 , Speed :  13.839918420589145  MB/s

# %%
b = bag.read_text('../pricing-kpi/data/ACN_full_*_13.csv', encoding='latin1').groupby(lambda x: x[10:16])
b = b.map_partitions(lambda x: x).map(lambda x: x[1]).flatten()
#print(b.take(2))
b.to_textfiles('test_bag_*.csv')
# Out:
# ['/Users/Axa/git/pricing-tool/test_bag_0.csv']

# %%
start_counter = perf_counter()
ddf = dd.read_csv('../pricing-kpi/data/ACN_full_*.csv', encoding='latin1', sep=';', dtype='object')
ddf.groupby('NUMCNT')
ddf.to_parquet('test.parquet')
ddf.head(1)
duration = stop_counter - start_counter
print('ok', duration)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-123-9d7aebe3815e> in <module>()
#       2 ddf = dd.read_csv('../pricing-kpi/data/ACN_full_*.csv', encoding='latin1', sep=';', dtype='object')
#       3 ddf.groupby('NUMCNT')
# ----> 4 ddf.to_parquet('test.parquet')
#       5 ddf.head(1)
#       6 duration = stop_counter - start_counter
#
# ~/git/pricing-tool/venv/lib/python3.6/site-packages/dask/dataframe/core.py in to_parquet(self, path, *args, **kwargs)
#    3618         from .io import to_parquet
#    3619
# -> 3620         return to_parquet(self, path, *args, **kwargs)
#    3621
#    3622     @derived_from(pd.DataFrame)
#
# ~/git/pricing-tool/venv/lib/python3.6/site-packages/dask/dataframe/io/parquet/core.py in to_parquet(df, path, engine, compression, write_index, append, ignore_divisions, partition_on, storage_options, write_metadata_file, compute, **kwargs)
# ...

# %%
1. export events
2. group by

# %%
start_counter = perf_counter()
i = 0
with open('./data/axaf_mrh_ddea_freq_tot.csv', 'r') as infile:
    for line in infile:
        line.split(',')
        #break
        i += 1
        if i>= 1000000:
            break
stop_counter = perf_counter()
duration = stop_counter - start_counter
print('ok', i, duration)
# Out:
# ok 1000000 8.2375369759975

# %%
pd.read_csv('./data/axaf_mrh_ddea_freq_tot.csv', nrows=10000).dtypes.astype(str).to_dict()
# Out:
# {'EXT_dens_pop': 'float64',
#  'EXT_part_respr_1p': 'float64',
#  'EXT_part_respr_5p': 'float64',
#  'EXT_part_secocc': 'float64',
#  'EXT_part_surf_inf40': 'float64',
#  'EXT_part_surf_plus100': 'float64',
#  'EXT_part_rev_15K29k': 'float64',
#  'EXT_part_men_lochlm': 'float64',
#  'EXT_part_men_pror': 'float64',
#  'EXT_part_pop_18a24a': 'float64',
#  'EXT_part_pop_65a79a': 'float64',
#  'EXT_part_respr_chauf_aut': 'float64',
#  'EXT_part_respr_chauf_col': 'float64',
#  'EXT_part_respr_chauf_ind': 'float64',
#  'EXT_part_respr_chauf_indelec': 'float64',
#  'EXT_part_repsr_sdb1': 'float64',
#  'EXT_part_repsr_sdb2': 'float64',
#  'EXT_part_lgt_co': 'float64',
#  'EXT_part_lgt_vac': 'float64',
#  'EXT_part_pop_15dipsup': 'float64',
#  'EXT_part_pop_15ssdip': 'float64',
#  'EXT_gdeville': 'object',
#  'AUTV_prix_sra_max': 'object',
#  'AUTV_prix_sra_min': 'object',
#  'AUTV_rm': 'object',
#  'AUTV_segment_max': 'object',
#  'AUTV_segment_min': 'object',
#  'CLI_banque': 'object',
# ...

# %%
dtypes = {
    'ID_numcnt': 'object',
    'HAB_inser': 'category',
    'POL_tr_capass': 'category',
    'annee': 'category',
    'anpol': 'float32',
    'HAB_nb_pieces': 'category',
    'POL_fr': 'category',
    'HAB_inhab': 'category',
    'HAB_qual': 'category',
    'CODIRIS': 'object',
    'XM': 'float32',
    'YM': 'float32',
    'CLI_cspf': 'category',
    'nbsinDDE': 'uint8',
    'Random': 'uint8',
    'HAB_anclg': 'category',
    'CLI_sit_fam2': 'category',
    'HAB_habit': 'category',
}

dask.config.set(scheduler='threads')

start_counter = perf_counter()
reader = pd.read_csv('./data/appart20092013.csv', dtype=dtypes, chunksize=100000, iterator=True)
#df = df.set_index('ID_numcnt')#.to_parquet('test_dask.parquet')
#df = df.groupby('ID_numcnt').apply(lambda x: x.count())
for i, chunk in reader:
    chunk.to_parquet("test_chunk.parquet", )
stop_counter = perf_counter()
duration = stop_counter - start_counter
print('Duration: ', duration, ', Speed : ', 527 / duration, ' MB/s')
# Out:
# /Users/Axa/git/pricing-tool/venv/lib/python3.6/site-packages/ipykernel_launcher.py:27: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
# Duration:  0.10597597199375741 , Speed :  4972.825349797625  MB/s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-cd151e3a8d5b> in <module>()
#      29 duration = stop_counter - start_counter
#      30 print('Duration: ', duration, ', Speed : ', 527 / duration, ' MB/s')
# ---> 31 df.head(100)
#
# ~/git/pricing-tool/venv/lib/python3.6/site-packages/dask/dataframe/core.py in head(self, n, npartitions, compute)
#     956             Whether to compute the result, default is True.
# ...

# %%
dtypes = {
    'ID_numcnt': 'object',
    'HAB_inser': 'category',
    'POL_tr_capass': 'category',
    'annee': 'category',
    'anpol': 'float32',
    'HAB_nb_pieces': 'category',
    'POL_fr': 'category',
    'HAB_inhab': 'category',
    'HAB_qual': 'category',
    'CODIRIS': 'object',
    'XM': 'float32',
    'YM': 'float32',
    'CLI_cspf': 'category',
    'nbsinDDE': 'uint8',
    'Random': 'uint8',
    'HAB_anclg': 'category',
    'CLI_sit_fam2': 'category',
    'HAB_habit': 'category',
}


start_counter = perf_counter()
df = dd.read_csv('./data/appart20092013.csv', dtype=dtypes)
stop_counter = perf_counter()
duration = stop_counter - start_counter
print('Duration: ', duration, ', Speed : ', 527 / duration, ' MB/s')

# %%
df.HAB_qual.nbytes

# %%
#%%timeit
df['A'] = df.HAB_qual.map({'P': 1.0, 'L': 1.2}).astype('float32')

# %%
#%%timeit
result = df.groupby(['HAB_qual'])['nbsinDDE'].mean()

# %%
result.compute()

# %%
# %%timeit
df['B'] = df.A * df.A

# %%
# %%timeit
df['B'] = df.A + df.A

# %%
list(df)

# %%
selection = [
 'HAB_inser',
 #'ID_numcnt',
 'POL_tr_capass',
 'annee',
 'anpol',
 'HAB_nb_pieces',
 'POL_fr',
 'HAB_inhab',
 'HAB_qual',
 #'CODIRIS',
 'XM',
 'YM',
 'CLI_cspf',
 'nbsinDDE',
 'Random',
 'HAB_anclg',
 'CLI_sit_fam2',
 'HAB_habit']

# %%
df.HAB_inhab.nbytes

# %%
df[selection].to_parquet('test.parquet')

# %%
df[selection].to_feather('test.feather')

# %%
df2 = pd.read_feather('test.feather')

# %%
# %%timeit
df2.anpol * df2.anpol

# %%
df3 = dd.read_parquet('test.parquet')

# %%
# %%timeit
df3.anpol * df3.anpol

# %% [markdown]
# ## Images
#
# ### Base
#
# - Policy (15)
# - Effective Start Date (8)
# - Effective End Date (8)
# - Emission Start Date (8)
# - Emission End Date (8)
# - Start Event (1)
# - End Event (1)
# - Exposure (4)
# - GWP  (4)
# - Portfolio  (15)
#
# ### Policy
#
# - Family (1)
# - Product (1)
# - Indicators (12)
# - Distribution (1)
# - ...
#
# ### Risk
#
# - ... (50)
#
# ### Claims
#
# - Nb (12)
# - amounts (12)

# %%
mrh_dtypes = {
    'EXT_dens_pop': 'category',
    'EXT_part_respr_1p': 'category',
    'EXT_part_respr_5p': 'category',
    'EXT_part_secocc': 'category',
    'EXT_part_surf_inf40': 'category',
    'EXT_part_surf_plus100': 'category',
    'EXT_part_rev_15K29k': 'category',
    'EXT_part_men_lochlm': 'category',
    'EXT_part_men_pror': 'category',
    'EXT_part_pop_18a24a': 'category',
    'EXT_part_pop_65a79a': 'category',
    'EXT_part_respr_chauf_aut': 'category',
    'EXT_part_respr_chauf_col': 'category',
    'EXT_part_respr_chauf_ind': 'category',
    'EXT_part_respr_chauf_indelec': 'category',
    'EXT_part_repsr_sdb1': 'category',
    'EXT_part_repsr_sdb2': 'category',
    'EXT_part_lgt_co': 'category',
    'EXT_part_lgt_vac': 'category',
    'EXT_part_pop_15dipsup': 'category',
    'EXT_part_pop_15ssdip': 'category',
    'EXT_gdeville': 'category',
    'AUTV_prix_sra_max': 'category',
    'AUTV_prix_sra_min': 'category',
    'AUTV_rm': 'category',
    'AUTV_segment_max': 'category',
    'AUTV_segment_min': 'category',
    'CLI_banque': 'category',
    'POL_cdopmrh': 'category',
    'POL_fract': 'category',
    'POL_cdregion': 'category',
    'HAB_cdresid': 'category',
    'CLI_sex': 'category',
    'POL_distrib': 'category',
    'AUTV_energie_es': 'category',
    'AUTV_energie_go': 'category',
    'AUTV_k8000_n': 'category',
    'AUTV_k8000_o': 'category',
    'AUTV_prix_sra_ad': 'category',
    'AUTV_prix_sra_ef': 'category',
    'AUTV_prix_sra_gi': 'category',
    'AUTV_prix_sra_jl': 'category',
    'AUTV_prix_sra_mn': 'category',
    'AUTV_prix_sra_supo': 'category',
    'AUTV_segment_0': 'category',
    'AUTV_segment_a': 'category',
    'AUTV_segment_b': 'category',
    'AUTV_segment_h': 'category',
    'AUTV_segment_m1': 'category',
    'AUTV_segment_m2': 'category',
    'AUTV_nb_rc_12': 'category',
    'AUTV_nb_rc_34': 'category',
    'AUTV_nb_rc_56': 'category',
    'AUTV_nb_rc_78': 'category',
    'AUTV_nb_rc_sup9': 'category',
    'AUTV_nb_vol_ab': 'category',
    'AUTV_nb_vol_cd': 'category',
    'AUTV_nb_vol_ef': 'category',
    'AUTV_nb_vol_gh': 'category',
    'AUTV_nb_vol_ij': 'category',
    'AUTV_nb_vol_supk': 'category',
    'HAB_inser': 'category',
    'POL_mtcapass': 'category',
    'CLI_indice': 'category',
    'AUTA_tot1a': 'category',
    'AUTA_tot2a': 'category',
    'AUTA_tot3a': 'category',
    'AUTA_tot4a': 'category',
    'POL_tx_objv': 'category',
    'POL_tr_capass': 'category',
    'CLI_age': 'category',
    'annee': 'category',
    'anpol': 'category',
    'CLI_nb_contrat': 'category',
    'CLI_nb_contrat_atr': 'category',
    'CLI_nb_contrat_aup': 'category',
    'CLI_nb_contrat_bqe': 'category',
    'CLI_nb_contrat_epa': 'category',
    'CLI_nb_contrat_hab': 'category',
    'CLI_nb_contrat_mot': 'category',
    'CLI_nb_contrat_mrp': 'category',
    'CLI_nb_contrat_pf': 'category',
    'CLI_nb_contrat_pju': 'category',
    'CLI_nb_contrat_prv': 'category',
    'CLI_nb_contrat_san': 'category',
    'HAB_nb_pieces': 'category',
    'CLI_nb_enfant': 'category',
    'POL_fr': 'category',
    'AUTA_b50_n': 'category',
    'AUTA_b50_o': 'category',
    'AUTA_rm_50': 'category',
    'AUTA_rm_5060': 'category',
    'AUTA_rm_6070': 'category',
    'AUTA_rm_7090': 'category',
    'AUTA_rm_inf50': 'category',
    'AUTA_rm_sup90': 'category',
    'HAB_surf_dep': 'category',
    'HAB_inhab': 'category',
    'AUTV_nb_rc': 'category',
    'AUTV_nb_vol': 'category',
    'POL_pac': 'category',
    'POL_paj': 'category',
    'POL_pan': 'category',
    'POL_pap': 'category',
    'POL_par': 'category',
    'CLI_prod_entree': 'category',
    'HAB_qual': 'category',
    'POL_ran': 'category',
    'CLI_top_atr': 'category',
    'CLI_top_aup': 'category',
    'CLI_top_bqe': 'category',
    'CLI_top_epa': 'category',
    'CLI_top_hab': 'category',
    'CLI_top_mot': 'category',
    'CLI_top_mrp': 'category',
    'CLI_top_pf': 'category',
    'CLI_top_pju': 'category',
    'CLI_top_prv': 'category',
    'CLI_top_san': 'category',
    'HAB_top_jardin': 'category',
    'CLI_tr_age': 'category',
    'CLI_tr_ancli': 'category',
    'CLI_tr_mtvi': 'category',
    'CLI_tr_pm': 'category',
    'HAB_habit_X_qual_X_inhab': 'category',
    'POL_mtobv': 'category',
    'POL_tr_tx_objv': 'category',
    'CLI_cspf': 'category',
    'REG_zoneAxa_a': 'category',
    'REG_zoneAxa_m': 'category',
    'nbsinDDE': 'uint8',
    'nbsinVOL': 'uint8',
    'nbsinRC': 'uint8',
    'nbsinBDG': 'uint8',
    'nbsinDELEC': 'uint8',
    'nbsinCATNAT': 'uint8',
    'nbsinCATNAT2': 'uint8',
    'nbsinCLIM': 'uint8',
    'chargeDDEm': 'float32',
    'chargeVOLm': 'float32',
    'chargeRCm': 'float32',
    'chargeBDGm': 'float32',
    'chargeDELECm': 'float32',
    'chargeCATNATm': 'float32',
    'chargeCLIMm': 'float32',
    'top_clim10M': 'category',
    'top_forfaitBDG': 'category',
    'top_forfaitCLIM': 'category',
    'top_forfaitDDE': 'category',
    'top_forfaitDELEC': 'category',
    'top_forfaitINC': 'category',
    'top_forfaitRC': 'category',
    'top_forfaitVOL': 'category',
    'top_sin_extreme': 'category',
    'chargeINCgr': 'float32',
    'nbsinINCgr': 'uint8',
    'chargeINCattri': 'float32',
    'nbsinINCattri': 'uint8',
    'nbsinINC': 'uint8',
    'Random': 'category',
    'HAB_anclg': 'category',
    'CLI_sit_fam2': 'category',
    'AUTA_rm': 'category',
    'HAB_hab': 'category',
    'HAB_habit': 'category',
    'POL_delec': 'category',
    'anpolDEL': 'category',
    'POL_vol': 'category',
    'anpolVOL': 'category',
    'CLI_tr_age_X_CSPf': 'category',
    'ddea_quant_freq_20': 'category',
    'ddea_quant_cm_10': 'category',
    'ddem_quant_freq_20': 'category',
    'ddem_quant_cm_20': 'category',
    'clim_quant_pp_20': 'category',
    'vol_quant_freq_20': 'category',
    'vol_quant_cm_20': 'category',
    'bdg_quant_freq_20': 'category',
    'bdg_quant_cm_20': 'category',
    'catnat_quant_pp_10': 'category',
    'fire_quant_freq_20': 'category',
    'HAB_habit_nbpieces': 'category',
    'HAB_qual_inhab': 'category',
    'EXT_superficie_m2_num': 'category',
    'newid': 'object',
    'POL_distrib_code': 'object',
    'Zone_inc_cm_iris': 'category',
    'Zone_inc_freq_iris': 'category',
    'zone_vol_cm_insee': 'category',
    'zone_vol_freq_insee': 'category'
 }
